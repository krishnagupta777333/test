# %%
import pandas as pd

df = pd.read_csv("townprice.csv")
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
dummies = pd.get_dummies(df.town)
dummies
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
merge = pd.concat([df,dummies],axis = "columns")
merge
# Out:
#                town  area   price  monroe township  robinsville  west windsor
# 0   monroe township  2600  550000                1            0             0
# 1   monroe township  3000  565000                1            0             0
# 2   monroe township  3200  610000                1            0             0
# 3   monroe township  3600  680000                1            0             0
# 4   monroe township  4000  725000                1            0             0
# 5      west windsor  2600  585000                0            0             1
# 6      west windsor  2800  615000                0            0             1
# 7      west windsor  3300  650000                0            0             1
# 8      west windsor  3600  710000                0            0             1
# 9       robinsville  2600  575000                0            1             0
# 10      robinsville  2900  600000                0            1             0
# ...

# %%
final = merge.drop(["town"],axis = "columns")
final
# Out:
#     area   price  monroe township  robinsville  west windsor
# 0   2600  550000                1            0             0
# 1   3000  565000                1            0             0
# 2   3200  610000                1            0             0
# 3   3600  680000                1            0             0
# 4   4000  725000                1            0             0
# 5   2600  585000                0            0             1
# 6   2800  615000                0            0             1
# 7   3300  650000                0            0             1
# 8   3600  710000                0            0             1
# 9   2600  575000                0            1             0
# 10  2900  600000                0            1             0
# 11  3100  620000                0            1             0
# 12  3600  695000                0            1             0

# %%
from sklearn.linear_model import LinearRegression

# %%
x = final.drop("price",axis = "columns")
x


#model = LinearRegression()
# Out:
#     area  monroe township  robinsville  west windsor
# 0   2600                1            0             0
# 1   3000                1            0             0
# 2   3200                1            0             0
# 3   3600                1            0             0
# 4   4000                1            0             0
# 5   2600                0            0             1
# 6   2800                0            0             1
# 7   3300                0            0             1
# 8   3600                0            0             1
# 9   2600                0            1             0
# 10  2900                0            1             0
# 11  3100                0            1             0
# 12  3600                0            1             0

# %%
y = final.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.predict([[28,1,0,0]])
# Out:
# array([213329.5205333])

# %%
model.score(x,y)
# Out:
# 0.9573929037221873

# %%
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
label.fit_transform(df.town)
# Out:
# array([0, 0, 0, 0, 0, 2, 2, 2, 2, 1, 1, 1, 1], dtype=int64)

# %%
df.town = label.fit_transform(df.town)

# %%
df
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()
#reg.fit(df[["town","area"]],df.price)

# %%
#reg.predict([[1,3000]])

# %%
x = df.drop(["price"],axis = "columns")
x
# Out:
#     town  area
# 0      0  2600
# 1      0  3000
# 2      0  3200
# 3      0  3600
# 4      0  4000
# 5      2  2600
# 6      2  2800
# 7      2  3300
# 8      2  3600
# 9      1  2600
# 10     1  2900
# 11     1  3100
# 12     1  3600

# %%
y = df.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
reg.fit(x,y)
reg.predict([[1,3400]])
# Out:
# array([695000], dtype=int64)

# %%
df1 = pd.read_csv("townprice.csv")
df1
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
merged =   pd.get_dummies(df1.town)
merged
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
finals =  pd.concat([df1,merged],axis = "columns")
finals
# Out:
#                town  area   price  monroe township  robinsville  west windsor
# 0   monroe township  2600  550000                1            0             0
# 1   monroe township  3000  565000                1            0             0
# 2   monroe township  3200  610000                1            0             0
# 3   monroe township  3600  680000                1            0             0
# 4   monroe township  4000  725000                1            0             0
# 5      west windsor  2600  585000                0            0             1
# 6      west windsor  2800  615000                0            0             1
# 7      west windsor  3300  650000                0            0             1
# 8      west windsor  3600  710000                0            0             1
# 9       robinsville  2600  575000                0            1             0
# 10      robinsville  2900  600000                0            1             0
# ...

# %%
abc = finals.drop("town",axis = "columns")
abc
# Out:
#     area   price  monroe township  robinsville  west windsor
# 0   2600  550000                1            0             0
# 1   3000  565000                1            0             0
# 2   3200  610000                1            0             0
# 3   3600  680000                1            0             0
# 4   4000  725000                1            0             0
# 5   2600  585000                0            0             1
# 6   2800  615000                0            0             1
# 7   3300  650000                0            0             1
# 8   3600  710000                0            0             1
# 9   2600  575000                0            1             0
# 10  2900  600000                0            1             0
# 11  3100  620000                0            1             0
# 12  3600  695000                0            1             0

# %%
x1 = abc.drop("price",axis = "columns")
x1
# Out:
#     area  monroe township  robinsville  west windsor
# 0   2600                1            0             0
# 1   3000                1            0             0
# 2   3200                1            0             0
# 3   3600                1            0             0
# 4   4000                1            0             0
# 5   2600                0            0             1
# 6   2800                0            0             1
# 7   3300                0            0             1
# 8   3600                0            0             1
# 9   2600                0            1             0
# 10  2900                0            1             0
# 11  3100                0            1             0
# 12  3600                0            1             0

# %%
y1 = abc.price
y1
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
reg1 = LinearRegression()
reg1.fit(x1,y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg1.predict([[2300,1,0,0]])
# Out:
# array([501640.50741778])

# %%
df1
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
df1.town = label.fit_transform(df1.town)
df1
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
from sklearn.linear_model import LogisticRegression
reg2 = LinearRegression()
reg2.fit(df1[["town","area"]],df1.price)
reg2.predict([[2,3500]])
# Out:
# array([695494.61739889])

# %%
x3 = df1.drop("price",axis = "columns")
x3
# Out:
#     town  area
# 0      0  2600
# 1      0  3000
# 2      0  3200
# 3      0  3600
# 4      0  4000
# 5      2  2600
# 6      2  2800
# 7      2  3300
# 8      2  3600
# 9      1  2600
# 10     1  2900
# 11     1  3100
# 12     1  3600

# %%
y3 = df1.price
y3
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
r = LinearRegression()
r.fit(x3,y3)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
r.predict([[0,3400]])
# Out:
# array([642663.66016875])
